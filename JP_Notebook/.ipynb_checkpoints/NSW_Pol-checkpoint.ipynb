# %%
# Import libraries dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %matplotlib inline  

# Print libraries version
lib = {'Pandas':pd, 'Numpy':np, 'Seaborn':sns}
for k, v in lib.items():
    ver = v.__version__
    print('{} Version {}'.format(k, ver))
# Out:
# Pandas Version 0.24.2
# Numpy Version 1.15.1
# Seaborn Version 0.9.0

# %%
# Set path to data file
url = 'https://raw.githubusercontent.com/Sparrow-72/NSW_Pol/master/Data_sets/Raw_data/Penalty_notice.csv'

# %%
# Read the data as csv file
df = pd.read_csv(url)

# %%
# Look at the data header for an initial idea of the data
df.head(3)
# Out:
#   OFFENCE_FINYEAR OFFENCE_MONTH  OFFENCE_CODE  \
# 0       2015-2016    01/07/2015         82616
# 1       2012-2013    01/01/2013         24703
# 2       2012-2013    01/01/2013         64007
#
#                                        OFFENCE_DESC      LEGISLATION  \
# 0       Park continuously for longer than permitted  ROAD RULES 2014
# 1  Exceed speed limit over 10km/h - Camera Detected  ROAD RULES 2008
# 2                 Proceed through red traffic arrow  ROAD RULES 2008
#
#   SECTION_CLAUSE  FACE_VALUE CAMERA_IND                  CAMERA_TYPE  \
# 0            205         106        NaN                          NaN
# 1             20        1215          Y  Mobile Digital Speed Camera
# 2             60         397        NaN                          NaN
#
#    LOCATION_CODE  ... RED_LIGHT_CAMERA_IND SPEED_CAMERA_IND SEATBELT_IND  \
# 0            NaN  ...                  NaN              NaN          NaN
# 1        28330.0  ...                  NaN                Y          NaN
# 2            NaN  ...                  NaN              NaN          NaN
#
#   MOBILE_PHONE_IND PARKING_IND CINS_IND FOOD_IND BICYCLE_TOY_ETC_IND  \
# 0              NaN           Y      NaN      NaN                 NaN
# 1              NaN         NaN      NaN      NaN                 NaN
# 2              NaN         NaN      NaN      NaN                 NaN
#
#   TOTAL_NUMBER TOTAL_VALUE
# 0        23009     2438954
# 1            1        1215
# 2           94       37318
#
# [3 rows x 25 columns]

# %%
# Get some basic info from the data frame, specially the data types, if there is missing values, and memory usage
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285444 entries, 0 to 285443
# Data columns (total 25 columns):
# OFFENCE_FINYEAR         285444 non-null object
# OFFENCE_MONTH           285444 non-null object
# OFFENCE_CODE            285444 non-null int64
# OFFENCE_DESC            285444 non-null object
# LEGISLATION             285444 non-null object
# SECTION_CLAUSE          285444 non-null object
# FACE_VALUE              285444 non-null int64
# CAMERA_IND              189348 non-null object
# CAMERA_TYPE             188415 non-null object
# LOCATION_CODE           188440 non-null float64
# LOCATION_DETAILS        188440 non-null object
# SCHOOL_ZONE_IND         27379 non-null object
# SPEED_BAND              192139 non-null object
# SPEED_IND               162607 non-null object
# POINT_TO_POINT_IND      2140 non-null object
# RED_LIGHT_CAMERA_IND    28395 non-null object
# SPEED_CAMERA_IND        152634 non-null object
# SEATBELT_IND            1550 non-null object
# MOBILE_PHONE_IND        282 non-null object
# PARKING_IND             10135 non-null object
# CINS_IND                707 non-null object
# FOOD_IND                912 non-null object
# BICYCLE_TOY_ETC_IND     2393 non-null object
# TOTAL_NUMBER            285444 non-null int64
# TOTAL_VALUE             285444 non-null int64
# dtypes: float64(1), int64(4), object(20)
# memory usage: 294.7 MB

# %%
# Get a list of dtypes by the columns
dtype_list = ['object', 'category', 'int64', 'float64']
for i in dtype_list:
    d_type = df.select_dtypes(include=i).columns.tolist()
    print('Datatype {} = {}'.format(i, d_type))
# Out:
# Datatype object = ['OFFENCE_FINYEAR', 'OFFENCE_MONTH', 'OFFENCE_DESC', 'LEGISLATION', 'SECTION_CLAUSE', 'CAMERA_IND', 'CAMERA_TYPE', 'LOCATION_DETAILS', 'SCHOOL_ZONE_IND', 'SPEED_BAND', 'SPEED_IND', 'POINT_TO_POINT_IND', 'RED_LIGHT_CAMERA_IND', 'SPEED_CAMERA_IND', 'SEATBELT_IND', 'MOBILE_PHONE_IND', 'PARKING_IND', 'CINS_IND', 'FOOD_IND', 'BICYCLE_TOY_ETC_IND']
# Datatype category = []
# Datatype int64 = ['OFFENCE_CODE', 'FACE_VALUE', 'TOTAL_NUMBER', 'TOTAL_VALUE']
# Datatype float64 = ['LOCATION_CODE']

# %%
# Pass a variable with the list of columns to drop from the data frame
df_drop = df.drop(['LEGISLATION', 'SECTION_CLAUSE'], axis='columns')

# %%
# Drop the columns from the data frame
df_lean = pd.DataFrame(df_drop)

# %%
# Check for missing values in columns with single unique values 
# Create a list for the columns
single_uniq = []
for k, v in df_lean.nunique().to_dict().items():
    miss_ = df_lean[k].isnull().sum()
    if miss_ > 0:
        if v == 1:
            unique_lst = pd.unique(df_lean[k].values.ravel()).tolist()
            single_uniq.append(k)
            print('{} = {}, ___________Values {}'.format(k,v, unique_lst))
# Out:
# CAMERA_IND = 1, ___________Values [nan, 'Y']
# SCHOOL_ZONE_IND = 1, ___________Values [nan, 'Y']
# SPEED_IND = 1, ___________Values [nan, 'Y']
# POINT_TO_POINT_IND = 1, ___________Values [nan, 'Y']
# RED_LIGHT_CAMERA_IND = 1, ___________Values [nan, 'Y']
# SPEED_CAMERA_IND = 1, ___________Values [nan, 'Y']
# SEATBELT_IND = 1, ___________Values [nan, 'Y']
# MOBILE_PHONE_IND = 1, ___________Values [nan, 'Y']
# PARKING_IND = 1, ___________Values ['Y', nan]
# CINS_IND = 1, ___________Values [nan, 'Y']
# FOOD_IND = 1, ___________Values [nan, 'Y']
# BICYCLE_TOY_ETC_IND = 1, ___________Values [nan, 'Y']

# %%
# Check for missing values in columns with multiple unique values 
# Create a list for the columns
multi_uniq = []
for k, v in df_lean.nunique().to_dict().items():
    miss_ = df_lean[k].isnull().sum()
    if miss_ > 0:
        if v > 1:
            unique_lst = pd.unique(df_lean[k].values.ravel()).tolist()
            multi_uniq.append(k)
            print('{} = {}, ___________Values {}'.format(k,v, unique_lst[:3]))
# Out:
# CAMERA_TYPE = 7, ___________Values [nan, 'Mobile Digital Speed Camera', 'Red Light / Speed Camera']
# LOCATION_CODE = 2295, ___________Values [nan, 28330.0, 7120.0]
# LOCATION_DETAILS = 1982, ___________Values [nan, 'WOODWARD STREET ORANGE SOUTHBOUND', 'SOUTH DOWLING STREET SURRY HILLS NORTHBOUND']
# SPEED_BAND = 6, ___________Values [nan, 'EXCEED SPEED OVER 10KM/H', 'NOT STOP AT RED LIGHT']

# %%
# Fill the missing values, in this case 'N' is appropriate
df_lean[single_uniq] = df_lean[single_uniq].fillna('N')
df_lean[multi_uniq] = df_lean[multi_uniq].fillna('N')

# %%
# Create variabled for data type conversion
# Convert to datetime
date_time = 'OFFENCE_MONTH'

# Convert to ordinal
ord_list = ['OFFENCE_FINYEAR','OFFENCE_DESC', 'CAMERA_IND', 'CAMERA_TYPE', 'LOCATION_CODE', 'LOCATION_DETAILS', 'SCHOOL_ZONE_IND', 'SPEED_BAND', 'SPEED_IND', 
        'POINT_TO_POINT_IND', 'RED_LIGHT_CAMERA_IND', 'SPEED_CAMERA_IND', 'SEATBELT_IND', 'MOBILE_PHONE_IND', 'PARKING_IND', 
        'CINS_IND', 'FOOD_IND', 'BICYCLE_TOY_ETC_IND']

# convert to float
float_list = ['FACE_VALUE', 'TOTAL_VALUE']

# Convert to int
int_list = ['OFFENCE_CODE', 'TOTAL_NUMBER']

# %%
# Convert to datetime so to read as time series
df_lean[date_time] = pd.to_datetime(df_lean[date_time], dayfirst=True)

# Convert to ordinal, doing so will save memory
df_lean[ord_list] = df_lean[ord_list].astype('category')

# Convert to int
df_lean[int_list] = df_lean[int_list].astype('int64')

# Convert to float
df_lean[float_list] = df_lean[float_list].astype('float64')

# %%
df_lean.head(300)
# Out:
#     OFFENCE_FINYEAR OFFENCE_MONTH  OFFENCE_CODE  \
# 0         2015-2016    2015-07-01         82616
# 1         2012-2013    2013-01-01         24703
# 2         2012-2013    2013-01-01         64007
# 3         2012-2013    2013-01-01         74703
# 4         2012-2013    2013-01-01         74703
# 5         2012-2013    2013-01-01         64575
# 6         2012-2013    2013-01-01         10283
# 7         2012-2013    2013-01-01         74460
# 8         2012-2013    2013-01-01         64406
# 9         2012-2013    2013-01-01         13708
# 10        2012-2013    2013-02-01         74701
# 11        2012-2013    2013-01-01         64117
# 12        2012-2013    2013-02-01         74704
# 13        2012-2013    2013-01-01          6784
# 14        2012-2013    2013-01-01          6754
# 15        2012-2013    2013-01-01         74702
# 16        2012-2013    2013-01-01         24702
# 17        2012-2013    2013-01-01         69060
# 18        2012-2013    2013-01-01         74254
# 19        2012-2013    2013-02-01         74079
# 20        2012-2013    2013-02-01         64916
# 21        2012-2013    2013-02-01          8407
# 22        2012-2013    2013-02-01         74735
# 23        2012-2013    2013-02-01          8402
# 24        2012-2013    2013-02-01         64554
# 25        2012-2013    2013-02-01         64123
# 26        2012-2013    2013-02-01         78080
# 27        2012-2013    2013-03-01         74704
# 28        2012-2013    2013-03-01         64257
# 29        2012-2013    2013-03-01         64294
# ..              ...           ...           ...
# 270       2014-2015    2014-10-01          8421
# 271       2014-2015    2014-09-01         74703
# 272       2014-2015    2014-10-01         74703
# 273       2014-2015    2014-10-01         81648
# 274       2014-2015    2014-10-01         74479
# 275       2014-2015    2014-09-01         74468
# 276       2014-2015    2014-10-01         78481
# 277       2014-2015    2014-10-01         74472
# 278       2014-2015    2014-10-01         15241
# 279       2014-2015    2014-11-01         80216
# 280       2014-2015    2014-10-01         64280
# 281       2014-2015    2014-10-01         74709
# 282       2014-2015    2014-11-01         80743
# 283       2014-2015    2014-11-01         64427
# 284       2014-2015    2014-11-01         64004
# 285       2014-2015    2014-11-01         74703
# 286       2014-2015    2014-10-01           797
# 287       2014-2015    2014-11-01         24705
# 288       2014-2015    2014-11-01         74705
# 289       2014-2015    2014-11-01         65813
# 290       2014-2015    2014-10-01         74705
# 291       2014-2015    2014-11-01         73108
# 292       2014-2015    2014-11-01         74703
# 293       2014-2015    2014-12-01         82950
# 294       2013-2014    2014-06-01         15351
# 295       2014-2015    2014-12-01         83063
# 296       2014-2015    2014-12-01         82770
# 297       2014-2015    2014-11-01         74701
# 298       2014-2015    2014-11-01         74703
# 299       2014-2015    2014-11-01         64081
#
#                                           OFFENCE_DESC  FACE_VALUE CAMERA_IND  \
# 0          Park continuously for longer than permitted       106.0          N
# 1     Exceed speed limit over 10km/h - Camera Detected      1215.0          Y
# 2                    Proceed through red traffic arrow       397.0          N
# 3     Exceed speed limit over 10km/h - Camera Detected       243.0          Y
# 4     Exceed speed limit over 10km/h - Camera Detected       243.0          Y
# 5                           Not reverse vehicle safely       165.0          N
# 6    Deposit litter on train/railway/railway land/m...       200.0          N
# 7      P1 driver exceed 90 km/h - over 20 km/h - Radar       417.0          N
# 8    Flash headlight/additional headlight not as pr...        99.0          N
# 9    Driver of network taxi-cab not wear approved n...        75.0          N
# 10   Exceed speed limit 10km/h and under - Camera D...       105.0          Y
# 11   Not give way to vehicle - right turn into road...       298.0          N
# 12   Exceed speed limit over 10 km/h - Camera Detec...       313.0          Y
# 13   Neglect/fail to comply with requirement under ...       500.0          N
# 14        Fail to pay clean-up notice fee - Individual       500.0          N
# 15   Exceed speed limit 10 km/h and under - Camera ...       173.0          Y
# 16   Exceed speed limit 10 km/h and under - Camera ...       865.0          Y
# 17   Not comply with P1 pillion passenger restrictions       298.0          N
# 18             P1 driver exceed 90 km/h - over 10 km/h       243.0          N
# 19         Fail to surrender number-plate to Authority        99.0          N
# 20   Drive across dividing lines to perform U-turn ...       298.0          N
# 21                    Not parallel park near road side        99.0          N
# 22    Drive in bus lane - Camera Detected - Individual       298.0          Y
# 23                     Disobey motor bike parking sign        99.0          N
# 24                               Drive on nature strip       298.0          N
# 25   Not move out of path of police or emergency ve...       397.0          N
# 26   Not give ticket for inspection on train or res...        50.0          N
# 27   Exceed speed limit over 10 km/h - Camera Detec...       313.0          Y
# 28     Not keep left of median strip - (motor vehicle)       298.0          N
# 29                                   Drive in bus lane       298.0          N
# ..                                                 ...         ...        ...
# 270                 Not park wholly within parking bay       104.0          N
# 271   Exceed speed limit over 10km/h - Camera Detected       254.0          Y
# 272   Exceed speed limit over 10km/h - Camera Detected       254.0          Y
# 273  Use Class A vehicle number plate obscured/defaced       415.0          N
# 274   P2 driver exceed 100 km/h - over 20 km/h - Lidar       436.0          N
# 275    P1 driver exceed 90 km/h - over 45 km/h - Radar      2252.0          N
# 276  Go onto or into or remain on or in running lin...       400.0          N
# 277  P2 driver exceed 100 km/h - 10 km/h and under ...       109.0          N
# 278  Licensee/employee/agent sell/supply liquor not...      1100.0          N
# 279  Driver not record required information after s...       307.0          N
# 280  Not give way (move from one line of traffic to...       311.0          N
# 281  Exceed speed limit over 45 km/h - Camera Detected      2252.0          Y
# 282  Driver fail to produce for inspection work dia...       615.0          N
# 283             Cross when pedestrian lights not green        69.0          N
# 284  Proceed through red traffic light (not toll bo...       415.0          N
# 285   Exceed speed limit over 10km/h - Camera Detected       254.0          Y
# 286     Obstruct person/vehicle/vessel in public place       200.0          N
# 287  Exceed speed limit over 20 km/h - Camera Detected      2180.0          Y
# 288   Exceed speed limit over 20km/h - Camera Detected       436.0          Y
# 289  Drive motor vehicle with person or animal in l...       519.0          N
# 290   Exceed speed limit over 20km/h - Camera Detected       436.0          Y
# 291  Person not wear appropriate lifejacket while b...       100.0          N
# 292   Exceed speed limit over 10km/h - Camera Detected       254.0          Y
# 293  Motor vehicle exceed speed limit - over 10 km/...       254.0          Y
# 294  Hotelier fail to display notice in relevant ar...       220.0          N
# 295  Motor vehicle exceed speed limit - 10 km/h and...       109.0          Y
# 296         Parallel park close to dividing line/strip       242.0          N
# 297  Exceed speed limit 10km/h and under - Camera D...       109.0          Y
# 298   Exceed speed limit over 10km/h - Camera Detected       254.0          Y
# 299     Not give way to vehicle/pedestrian (stop sign)       311.0          N
#
#                        CAMERA_TYPE LOCATION_CODE  \
# 0                                N             N
# 1      Mobile Digital Speed Camera         28330
# 2                                N             N
# 3         Red Light / Speed Camera          7120
# 4       Fixed Digital Speed Camera          9582
# 5                                N             N
# 6                                N             N
# 7                                N             N
# 8                                N             N
# 9                                N             N
# 10      Fixed Digital Speed Camera          9821
# 11                               N             N
# 12      Fixed Digital Speed Camera          9840
# 13                               N             N
# 14                               N             N
# 15      Fixed Digital Speed Camera          9829
# 16      Fixed Digital Speed Camera          9843
# 17                               N             N
# 18                               N             N
# 19                               N             N
# 20                               N             N
# 21                               N             N
# 22   Fixed Digital Bus Lane Camera          8442
# 23                               N             N
# 24                               N             N
# 25                               N             N
# 26                               N             N
# 27      Fixed Digital Speed Camera          9826
# 28                               N             N
# 29                               N             N
# ..                             ...           ...
# 270                              N             N
# 271    Mobile Digital Speed Camera         18270
# 272       Red Light / Speed Camera          7270
# 273                              N             N
# 274                              N             N
# 275                              N             N
# 276                              N             N
# 277                              N             N
# 278                              N             N
# 279                              N             N
# 280                              N             N
# 281     Fixed Digital Speed Camera          9596
# 282                              N             N
# 283                              N             N
# 284                              N             N
# 285    Mobile Digital Speed Camera         11732
# 286                              N             N
# 287       Red Light / Speed Camera          7171
# 288    Mobile Digital Speed Camera         25383
# 289                              N             N
# 290       Red Light / Speed Camera          7300
# 291                              N             N
# 292    Mobile Digital Speed Camera         18780
# 293     Fixed Digital Speed Camera          9837
# 294                              N             N
# 295     Fixed Digital Speed Camera          9552
# 296                              N             N
# 297    Mobile Digital Speed Camera         28791
# 298    Mobile Digital Speed Camera         11764
# 299                              N             N
#
#                                       LOCATION_DETAILS SCHOOL_ZONE_IND  ...  \
# 0                                                    N               N  ...
# 1                    WOODWARD STREET ORANGE SOUTHBOUND               N  ...
# 2                                                    N               N  ...
# 3          SOUTH DOWLING STREET SURRY HILLS NORTHBOUND               N  ...
# 4              PACIFIC HIGHWAY MAYFIELD WEST EASTBOUND               N  ...
# 5                                                    N               N  ...
# 6                                                    N               N  ...
# 7                                                    N               N  ...
# 8                                                    N               N  ...
# 9                                                    N               N  ...
# 10               BIGGE STREET LIVERPOOL (Z) NORTHBOUND               N  ...
# 11                                                   N               N  ...
# 12               VICTORIA ROAD RYDALMERE (Z) WESTBOUND               Y  ...
# 13                                                   N               N  ...
# 14                                                   N               N  ...
# 15                FOREST ROAD  PENSHURST (Z) EASTBOUND               Y  ...
# 16            PACIFIC HIGHWAY WAHROONGA (Z) NORTHBOUND               Y  ...
# 17                                                   N               N  ...
# 18                                                   N               N  ...
# 19                                                   N               N  ...
# 20                                                   N               N  ...
# 21                                                   N               N  ...
# 22                         GEORGE ST SYDNEY SOUTHBOUND               N  ...
# 23                                                   N               N  ...
# 24                                                   N               N  ...
# 25                                                   N               N  ...
# 26                                                   N               N  ...
# 27             PITTWATER ROAD NARRABEEN (Z) NORTHBOUND               Y  ...
# 28                                                   N               N  ...
# 29                                                   N               N  ...
# ..                                                 ...             ...  ...
# 270                                                  N               N  ...
# 271                   THE LAKES WAY FORSTER NORTHBOUND               N  ...
# 272  LANE COVE ROAD (NORTHBOUND) NORTH RYDE NORTHBOUND               N  ...
# 273                                                  N               N  ...
# 274                                                  N               N  ...
# 275                                                  N               N  ...
# 276                                                  N               N  ...
# 277                                                  N               N  ...
# 278                                                  N               N  ...
# 279                                                  N               N  ...
# 280                                                  N               N  ...
# 281                 LANYON DRIVE QUEANBEYAN NORTHBOUND               N  ...
# 282                                                  N               N  ...
# 283                                                  N               N  ...
# 284                                                  N               N  ...
# 285       NEW ENGLAND HIGHWAY EAST MAITLAND NORTHBOUND               N  ...
# 286                                                  N               N  ...
# 287                DOBROYD PARADE HABERFIELD WESTBOUND               N  ...
# 288                 MAJORS BAY ROAD CONCORD SOUTHBOUND               N  ...
# 289                                                  N               Y  ...
# 290                     RAWSON STREET AUBURN WESTBOUND               N  ...
# 291                                                  N               N  ...
# 292               SPRINGHILL ROAD WOLLONGONG EASTBOUND               N  ...
# 293          CLEVELAND STREET MOORE PARK (Z) EASTBOUND               N  ...
# 294                                                  N               N  ...
# 295       M5 MOTORWAY (WESTBOUND)  ARNCLIFFE WESTBOUND               N  ...
# 296                                                  N               N  ...
# 297                  KINGHORNE STREET NOWRA NORTHBOUND               N  ...
# 298                  GLEBE ROAD THE JUNCTION WESTBOUND               N  ...
# 299                                                  N               N  ...
#
#     RED_LIGHT_CAMERA_IND SPEED_CAMERA_IND SEATBELT_IND MOBILE_PHONE_IND  \
# 0                      N                N            N                N
# 1                      N                Y            N                N
# 2                      N                N            N                N
# 3                      N                Y            N                N
# 4                      N                Y            N                N
# 5                      N                N            N                N
# 6                      N                N            N                N
# 7                      N                N            N                N
# 8                      N                N            N                N
# 9                      N                N            N                N
# 10                     N                Y            N                N
# 11                     N                N            N                N
# 12                     N                Y            N                N
# 13                     N                N            N                N
# 14                     N                N            N                N
# 15                     N                Y            N                N
# 16                     N                Y            N                N
# 17                     N                N            N                N
# 18                     N                N            N                N
# 19                     N                N            N                N
# 20                     N                N            N                N
# 21                     N                N            N                N
# 22                     N                N            N                N
# 23                     N                N            N                N
# 24                     N                N            N                N
# 25                     N                N            N                N
# 26                     N                N            N                N
# 27                     N                Y            N                N
# 28                     N                N            N                N
# 29                     N                N            N                N
# ..                   ...              ...          ...              ...
# 270                    N                N            N                N
# 271                    N                Y            N                N
# 272                    N                Y            N                N
# 273                    N                N            N                N
# 274                    N                N            N                N
# 275                    N                N            N                N
# 276                    N                N            N                N
# 277                    N                N            N                N
# 278                    N                N            N                N
# 279                    N                N            N                N
# 280                    N                N            N                N
# 281                    N                Y            N                N
# 282                    N                N            N                N
# 283                    N                N            N                N
# 284                    N                N            N                N
# 285                    N                Y            N                N
# 286                    N                N            N                N
# 287                    N                Y            N                N
# 288                    N                Y            N                N
# 289                    N                N            N                N
# 290                    N                Y            N                N
# 291                    N                N            N                N
# 292                    N                Y            N                N
# 293                    N                Y            N                N
# 294                    N                N            N                N
# 295                    N                Y            N                N
# 296                    N                N            N                N
# 297                    N                Y            N                N
# 298                    N                Y            N                N
# 299                    N                N            N                N
#
#     PARKING_IND CINS_IND FOOD_IND BICYCLE_TOY_ETC_IND TOTAL_NUMBER TOTAL_VALUE
# 0             Y        N        N                   N        23009   2438954.0
# 1             N        N        N                   N            1      1215.0
# 2             N        N        N                   N           94     37318.0
# 3             N        N        N                   N           15      3645.0
# 4             N        N        N                   N           21      5103.0
# 5             N        N        N                   N           81     13365.0
# 6             N        N        N                   N            8      1600.0
# 7             N        N        N                   N           33     13761.0
# 8             N        N        N                   N           17      1683.0
# 9             N        N        N                   N           25      1875.0
# 10            N        N        N                   N           62      6510.0
# 11            N        N        N                   N           13      3874.0
# 12            N        N        N                   N           12      3756.0
# 13            N        N        N                   N            8      4000.0
# 14            N        N        N                   N            1       500.0
# 15            N        N        N                   N            2       346.0
# 16            N        N        N                   N            2      1730.0
# 17            N        N        N                   N           11      3278.0
# 18            N        N        N                   N           31      7533.0
# 19            N        N        N                   N            4       396.0
# 20            N        N        N                   N          227     67646.0
# 21            Y        N        N                   N           18      1782.0
# 22            N        N        N                   N            3       894.0
# 23            Y        N        N                   N           88      8712.0
# 24            N        N        N                   N            3       894.0
# 25            N        N        N                   N            5      1985.0
# 26            N        N        N                   N           35      1750.0
# 27            N        N        N                   N           53     16589.0
# 28            N        N        N                   N           30      8940.0
# 29            N        N        N                   N          246     73308.0
# ..          ...      ...      ...                 ...          ...         ...
# 270           Y        N        N                   N          430     44720.0
# 271           N        N        N                   N            4      1016.0
# 272           N        N        N                   N           35      8890.0
# 273           N        N        N                   N          149     61835.0
# 274           N        N        N                   N           60     26160.0
# 275           N        N        N                   N            2      4504.0
# 276           N        N        N                   N           27     10800.0
# 277           N        N        N                   N           15      1635.0
# 278           N        N        N                   N            3      3300.0
# 279           N        N        N                   N           60     18420.0
# 280           N        N        N                   N            4      1244.0
# 281           N        N        N                   N            1      2252.0
# 282           N        N        N                   N            9      5535.0
# 283           N        N        N                   N          527     36363.0
# 284           N        N        N                   N          115     47725.0
# 285           N        N        N                   N           20      5080.0
# 286           N        Y        N                   N            3       600.0
# 287           N        N        N                   N            1      2180.0
# 288           N        N        N                   N            2       872.0
# 289           N        N        N                   N            1       519.0
# 290           N        N        N                   N            1       436.0
# 291           N        N        N                   N            1       100.0
# 292           N        N        N                   N            1       254.0
# 293           N        N        N                   N          388     98552.0
# 294           N        N        N                   N            1       220.0
# 295           N        N        N                   N          265     28885.0
# 296           Y        N        N                   N          395     95590.0
# 297           N        N        N                   N            1       109.0
# 298           N        N        N                   N            3       762.0
# 299           N        N        N                   N           12      3732.0
#
# [300 rows x 23 columns]

# %%
# Final check to make sure the data frame is as expected. Note, how the memory usage was reduced, due to data type conversion
df_lean.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285444 entries, 0 to 285443
# Data columns (total 23 columns):
# OFFENCE_FINYEAR         285444 non-null category
# OFFENCE_MONTH           285444 non-null datetime64[ns]
# OFFENCE_CODE            285444 non-null int64
# OFFENCE_DESC            285444 non-null category
# FACE_VALUE              285444 non-null float64
# CAMERA_IND              285444 non-null category
# CAMERA_TYPE             285444 non-null category
# LOCATION_CODE           285444 non-null category
# LOCATION_DETAILS        285444 non-null category
# SCHOOL_ZONE_IND         285444 non-null category
# SPEED_BAND              285444 non-null category
# SPEED_IND               285444 non-null category
# POINT_TO_POINT_IND      285444 non-null category
# RED_LIGHT_CAMERA_IND    285444 non-null category
# SPEED_CAMERA_IND        285444 non-null category
# SEATBELT_IND            285444 non-null category
# MOBILE_PHONE_IND        285444 non-null category
# PARKING_IND             285444 non-null category
# CINS_IND                285444 non-null category
# FOOD_IND                285444 non-null category
# BICYCLE_TOY_ETC_IND     285444 non-null category
# TOTAL_NUMBER            285444 non-null int64
# TOTAL_VALUE             285444 non-null float64
# dtypes: category(18), datetime64[ns](1), float64(2), int64(2)
# memory usage: 17.8 MB

# %%
# Set path to save data file
file_path_to_save = '..\Data_sets\Intermediate_data'

# %%
# Save data file to csv format
df_lean.to_csv(file_path_to_save+'\pol_data_clean.csv', index=False)
